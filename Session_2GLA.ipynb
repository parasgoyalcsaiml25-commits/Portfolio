# %% [markdown]
# <a href="https://colab.research.google.com/github/ThakurAmit07/AIML_BOOTCAMP2026/blob/main/Session_2GLA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Gla")
print("Namaste India")
# Out:
# Hello Gla
# Namaste India

# %%
a="Ishan"
b=7
c=0.007
d=True
print(a,b,c,d)
# Out:
# Amit 7 0.007 True

# %%
marks=[45,60,75,90,40]
for i in marks:
  if i>40:
    print("pass")
  else:
    print("fail")
# Out:
# fail
# pass
# pass
# pass
# fail

# %%
a=[0,1,-1,2,-2,4,5,90,67]
for i in a:
  if i>0:
    print("Positive")
  elif i<0:
    print("Neg")
  else:
    print(0)
# Out:
# 0
# Positive
# Neg
# Positive
# Neg
# Positive
# Positive
# Positive
# Positive

# %%
subs=["maths","physics","chemistry","english","hindi"]
print(subs[0])
print(subs[4])
# Out:
# maths
# hindi

# %%
l=[10,29,40,35,65]
def check(l):
  if l>=27:
    return "Pass"
